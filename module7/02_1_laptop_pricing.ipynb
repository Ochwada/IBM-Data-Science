# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod1.csv"
df = pd.read_csv(filepath)
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    object
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    object
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  234 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       233 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 24.3+ KB

# %%
# Note that we can update the Screen_Size_cm column such that all values are rounded to nearest 2 decimal places by using numpy.round()
df["Screen_Size_cm"] = np.round(df[["Screen_Size_cm"]], 2)
df.head(5)
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           35.56            1.6       8             256       1.60    978
# 1           39.62            2.0       4             256       2.20    634
# 2           39.62            2.7       8             256       2.20    946
# 3           33.78            1.6       8             128       1.22   1244
# 4           39.62            1.8       8             256       1.91    837

# %%
df.describe(include= "all")
# Out:
#         Unnamed: 0 Manufacturer    Category   Screen         GPU          OS  \
# count   238.000000          238  238.000000      238  238.000000  238.000000
# unique         NaN           11         NaN        2         NaN         NaN
# top            NaN         Dell         NaN  Full HD         NaN         NaN
# freq           NaN           71         NaN      161         NaN         NaN
# mean    118.500000          NaN    3.205882      NaN    2.151261    1.058824
# std      68.848868          NaN    0.776533      NaN    0.638282    0.235790
# min       0.000000          NaN    1.000000      NaN    1.000000    1.000000
# 25%      59.250000          NaN    3.000000      NaN    2.000000    1.000000
# 50%     118.500000          NaN    3.000000      NaN    2.000000    1.000000
# 75%     177.750000          NaN    4.000000      NaN    3.000000    1.000000
# max     237.000000          NaN    5.000000      NaN    3.000000    2.000000
#
# ...

# %%
missing_values = df.isnull()
missing_values.head()
# Out:
#    Unnamed: 0  Manufacturer  Category  Screen    GPU     OS  CPU_core  \
# 0       False         False     False   False  False  False     False
# 1       False         False     False   False  False  False     False
# 2       False         False     False   False  False  False     False
# 3       False         False     False   False  False  False     False
# 4       False         False     False   False  False  False     False
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           False          False   False           False      False  False
# 1           False          False   False           False      False  False
# 2           False          False   False           False      False  False
# 3           False          False   False           False      False  False
# 4           False          False   False           False      False  False

# %%
for column in missing_values.columns.values.tolist():
    print(column)
    print(missing_values[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# False    238
# Name: Unnamed: 0, dtype: int64
#
# Manufacturer
# False    238
# Name: Manufacturer, dtype: int64
#
# Category
# False    238
# Name: Category, dtype: int64
#
# Screen
# False    238
# Name: Screen, dtype: int64
#
# GPU
# False    238
# Name: GPU, dtype: int64
#
# OS
# False    238
# Name: OS, dtype: int64
#
# CPU_core
# False    238
# Name: CPU_core, dtype: int64
#
# Screen_Size_cm
# False    234
# True       4
# Name: Screen_Size_cm, dtype: int64
#
# CPU_frequency
# False    238
# Name: CPU_frequency, dtype: int64
#
# RAM_GB
# False    238
# Name: RAM_GB, dtype: int64
#
# Storage_GB_SSD
# False    238
# Name: Storage_GB_SSD, dtype: int64
#
# Weight_kg
# False    233
# True       5
# Name: Weight_kg, dtype: int64
#
# Price
# False    238
# Name: Price, dtype: int64

# %%
# Replace the missing values of weight with the average value of the attribute.
mean_weight_kg = df["Weight_kg"].astype('float').mean(axis=0)
#print(mean_weight_kg)
df["Weight_kg"].replace(np.nan, mean_weight_kg, inplace=True)
df["Weight_kg"].tail()
# Out:
# 233    1.70
# 234    1.20
# 235    1.36
# 236    2.40
# 237    1.95
# Name: Weight_kg, dtype: float64

# %%
# change data m type
df["Weight_kg"] = df["Weight_kg"].astype("float")
df["Screen_Size_cm"] = df["Screen_Size_cm"].astype("float")

# df[["Weight_kg","Screen_Size_cm"]] = df[["Weight_kg","Screen_Size_cm"]].astype("float")

df.dtypes
# Out:
# Unnamed: 0          int64
# Manufacturer       object
# Category            int64
# Screen             object
# GPU                 int64
# OS                  int64
# CPU_core            int64
# Screen_Size_cm    float64
# CPU_frequency     float64
# RAM_GB              int64
# Storage_GB_SSD      int64
# Weight_kg         float64
# Price               int64
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           35.56            1.6       8             256       1.60    978
# 1           39.62            2.0       4             256       2.20    634
# 2           39.62            2.7       8             256       2.20    946
# 3           33.78            1.6       8             128       1.22   1244
# 4           39.62            1.8       8             256       1.91    837

# %%
# Data Standardization
# transform cm to inch by mathematical operation (1 inch = 2.54 cm)

df["Screen_Size_cm"] = df["Screen_Size_cm"]/ 2.54
df["Weight_kg"] = df["Weight_kg"]*2.205

# rename column name from "Screen_Size_cm" to "Screen_Size_inch" (also weights)
df.rename(columns={"Screen_Size_cm": "Screen_Size_inch", "Weight_kg": "Weight_pounds"}, inplace= True)


# check your transformed data 
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0         14.000000            1.6       8             256        3.52800
# 1         15.598425            2.0       4             256        4.85100
# 2         15.598425            2.7       8             256        4.85100
# 3         13.299213            1.6       8             128        2.69010
# 4         15.598425            1.8       8             256        4.21155
#
#    Price
# 0    978
# 1    634
# 2    946
# 3   1244
# 4    837

# %%
df["CPU_frequency"]= df["CPU_frequency"]/ df["CPU_frequency"].max()

# %%
df["Price"].dtype
# Out:
# dtype('int64')

# %%
#  binning Price
bins = np.linspace(min(df["Price"]), max(df["Price"]), 4)
bins
# Out:
# array([ 527.        , 1621.33333333, 2715.66666667, 3810.        ])

# %%
bin_groups = ["low", "medium", "high"]
df["Price_Range"] = pd.cut(df["Price"], bins, labels= bin_groups, include_lowest=True)
df[["Price", "Price_Range"]].head(10)
# Out:
#    Price Price_Range
# 0    978         low
# 1    634         low
# 2    946         low
# 3   1244         low
# 4    837         low
# 5   1016         low
# 6   1117         low
# 7    866         low
# 8    812         low
# 9   1068         low

# %%
from matplotlib import pyplot

#pyplot.bar(bin_groups, df["Price_Range"].value_counts())
plt.bar(bin_groups, df["Price_Range"].value_counts())
plt.xlabel("Price")
plt.ylabel("count")
plt.title("Price bins")
# Out:
# Text(0.5, 1.0, 'Price bins')

# %%
df.head(5)
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0         14.000000       0.551724       8             256        3.52800
# 1         15.598425       0.689655       4             256        4.85100
# 2         15.598425       0.931034       8             256        4.85100
# 3         13.299213       0.551724       8             128        2.69010
# 4         15.598425       0.620690       8             256        4.21155
#
#    Price Price_Range
# 0    978         low
# 1    634         low
# 2    946         low
# 3   1244         low
# ...

# %%
dummy_var = pd.get_dummies(df["Screen"])
dummy_var.head(5)
# Out:
#    Full HD  IPS Panel
# 0        0          1
# 1        1          0
# 2        1          0
# 3        0          1
# 4        1          0

# %%
dummy_var.rename(columns={'Full HD': "Screen-Full_HD", 
                          "IPS Panel":"Screen-IPS_pane"}, 
                          inplace= True )

dummy_var.head(5)
# Out:
#    Screen-Full_HD  Screen-IPS_pane
# 0               0                1
# 1               1                0
# 2               1                0
# 3               0                1
# 4               1                0

# %%
df = pd.concat([df, dummy_var], axis=1)

# drop original column "Screen" from "df"
df.drop("Screen", axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inch  \
# 0           0         Acer         4    2   1         5         14.000000
# 1           1         Dell         3    1   1         3         15.598425
# 2           2         Dell         3    1   1         7         15.598425
# 3           3         Dell         4    2   1         5         13.299213
# 4           4           HP         4    2   1         7         15.598425
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  Price Price_Range  \
# 0       0.551724       8             256        3.52800    978         low
# 1       0.689655       4             256        4.85100    634         low
# 2       0.931034       8             256        4.85100    946         low
# 3       0.551724       8             128        2.69010   1244         low
# 4       0.620690       8             256        4.21155    837         low
#
#    Screen-Full_HD  Screen-IPS_pane
# ...
